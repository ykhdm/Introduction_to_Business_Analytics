# %% [markdown]
# <!DOCTYPE html>
# <html lang="de">
# <head>
# <meta charset="UTF-8">
# <style>
#   body { font-family: system-ui, sans-serif; background: #f5f4f0; display: flex; justify-content: center; padding: 2rem; }
#   .card { background: #fff; border-radius: 16px; padding: 1.5rem; box-shadow: 0 2px 12px rgba(0,0,0,0.08); max-width: 720px; width: 100%; }
# </style>
# </head>
# <body>
# <div class="card">
# <svg width="100%" viewBox="0 0 680 500" role="img">
#   <title>Sternschema: SPY Golden Cross Data Mart</title>
#   <defs>
#     <marker id="arrow" viewBox="0 0 10 10" refX="8" refY="5" markerWidth="6" markerHeight="6" orient="auto-start-reverse">
#       <path d="M2 1L8 5L2 9" fill="none" stroke="context-stroke" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"/>
#     </marker>
#   </defs>
#
#   <!-- dim_date -->
#   <rect x="30" y="100" width="180" height="220" rx="8" fill="#fff" stroke="#ccc" stroke-width="0.8"/>
#   <rect x="30" y="100" width="180" height="38" rx="8" fill="#f1efe8" stroke="#ccc" stroke-width="0.8"/>
#   <rect x="30" y="124" width="180" height="14" fill="#f1efe8" stroke="none"/>
#   <text font-family="system-ui,sans-serif" font-size="13" font-weight="500" x="120" y="123" text-anchor="middle" dominant-baseline="central" fill="#2c2c2a">dim_date</text>
#   <text font-family="system-ui,sans-serif" font-size="12" x="50" y="158" dominant-baseline="central" fill="#185FA5" font-weight="500">PK  date_id</text>
#   <line x1="30" y1="170" x2="210" y2="170" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="50" y="188" dominant-baseline="central" fill="#444">date</text>
#   <line x1="30" y1="200" x2="210" y2="200" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="50" y="218" dominant-baseline="central" fill="#444">year</text>
#   <line x1="30" y1="230" x2="210" y2="230" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="50" y="248" dominant-baseline="central" fill="#444">month</text>
#   <line x1="30" y1="260" x2="210" y2="260" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="50" y="278" dominant-baseline="central" fill="#444">weekday</text>
#   <line x1="30" y1="290" x2="210" y2="290" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="50" y="308" dominant-baseline="central" fill="#444">is_trading_day</text>
#
#   <!-- fact_market_signal -->
#   <rect x="240" y="60" width="200" height="300" rx="8" fill="#fff" stroke="#185FA5" stroke-width="1.2"/>
#   <rect x="240" y="60" width="200" height="38" rx="8" fill="#E6F1FB" stroke="#185FA5" stroke-width="1.2"/>
#   <rect x="241" y="84" width="198" height="15" fill="#E6F1FB" stroke="none"/>
#   <text font-family="system-ui,sans-serif" font-size="13" font-weight="500" x="340" y="83" text-anchor="middle" dominant-baseline="central" fill="#0C447C">fact_market_signal</text>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="118" dominant-baseline="central" fill="#185FA5" font-weight="500">PK  signal_id</text>
#   <line x1="240" y1="130" x2="440" y2="130" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="148" dominant-baseline="central" fill="#993C1D" font-weight="500">FK  date_id</text>
#   <line x1="240" y1="160" x2="440" y2="160" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="178" dominant-baseline="central" fill="#993C1D" font-weight="500">FK  stock_id</text>
#   <line x1="240" y1="190" x2="440" y2="190" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="208" dominant-baseline="central" fill="#444">close_price</text>
#   <line x1="240" y1="220" x2="440" y2="220" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="238" dominant-baseline="central" fill="#444">ma_50</text>
#   <line x1="240" y1="250" x2="440" y2="250" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="268" dominant-baseline="central" fill="#444">ma_200</text>
#   <line x1="240" y1="280" x2="440" y2="280" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="298" dominant-baseline="central" fill="#444">golden_cross  (0/1)</text>
#   <line x1="240" y1="310" x2="440" y2="310" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="260" y="328" dominant-baseline="central" fill="#444">ma_diff</text>
#
#   <!-- dim_stock -->
#   <rect x="470" y="100" width="180" height="190" rx="8" fill="#fff" stroke="#ccc" stroke-width="0.8"/>
#   <rect x="470" y="100" width="180" height="38" rx="8" fill="#f1efe8" stroke="#ccc" stroke-width="0.8"/>
#   <rect x="470" y="124" width="180" height="15" fill="#f1efe8" stroke="none"/>
#   <text font-family="system-ui,sans-serif" font-size="13" font-weight="500" x="560" y="123" text-anchor="middle" dominant-baseline="central" fill="#2c2c2a">dim_stock</text>
#   <text font-family="system-ui,sans-serif" font-size="12" x="490" y="158" dominant-baseline="central" fill="#185FA5" font-weight="500">PK  stock_id</text>
#   <line x1="470" y1="170" x2="650" y2="170" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="490" y="188" dominant-baseline="central" fill="#444">ticker  (SPY)</text>
#   <line x1="470" y1="200" x2="650" y2="200" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="490" y="218" dominant-baseline="central" fill="#444">name</text>
#   <line x1="470" y1="230" x2="650" y2="230" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="490" y="248" dominant-baseline="central" fill="#444">asset_class</text>
#   <line x1="470" y1="260" x2="650" y2="260" stroke="#e0ddd4" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="490" y="278" dominant-baseline="central" fill="#444">exchange</text>
#
#   <!-- Beziehungslinien -->
#   <line x1="210" y1="210" x2="238" y2="175" stroke="#888" stroke-width="1.2" marker-end="url(#arrow)"/>
#   <line x1="470" y1="195" x2="442" y2="185" stroke="#888" stroke-width="1.2" marker-end="url(#arrow)"/>
#   <text font-family="system-ui,sans-serif" font-size="11" x="216" y="202" dominant-baseline="central" fill="#888">1</text>
#   <text font-family="system-ui,sans-serif" font-size="11" x="236" y="190" dominant-baseline="central" fill="#888">N</text>
#   <text font-family="system-ui,sans-serif" font-size="11" x="458" y="192" dominant-baseline="central" fill="#888">1</text>
#   <text font-family="system-ui,sans-serif" font-size="11" x="444" y="182" dominant-baseline="central" fill="#888">N</text>
#
#   <!-- Legende -->
#   <rect x="30" y="420" width="290" height="52" rx="6" fill="#f5f4f0" stroke="#ccc" stroke-width="0.5"/>
#   <text font-family="system-ui,sans-serif" font-size="12" x="46" y="440" dominant-baseline="central" fill="#185FA5" font-weight="500">PK</text>
#   <text font-family="system-ui,sans-serif" font-size="12" x="66" y="440" dominant-baseline="central" fill="#444">Primärschlüssel</text>
#   <text font-family="system-ui,sans-serif" font-size="12" x="46" y="460" dominant-baseline="central" fill="#993C1D" font-weight="500">FK</text>
#   <text font-family="system-ui,sans-serif" font-size="12" x="66" y="460" dominant-baseline="central" fill="#444">Fremdschlüssel (Verbindung zur Fact-Tabelle)</text>
#
#   <text font-family="system-ui,sans-serif" font-size="11" x="340" y="468" text-anchor="middle" dominant-baseline="central" fill="#888">Sternschema — SPY Golden Cross Data Mart</text>
# </svg>
# </div>
# </body>
# </html>
